# %%
import pandas as pd

# %%
matches = pd.read_csv("final_dataset_epl_stats.csv", index_col=0)

# %%
matches.head()
# Out:
#          date            team     opponent   home_player_1    home_player_2  \
# 0  2022-08-05  Crystal Palace      Arsenal   VicenteGuaita   NathanielClyne
# 1  2022-08-06     Bournemouth  Aston Villa     MarkTravers      ChrisMepham
# 2  2022-08-06         Everton      Chelsea  JordanPickford   JamesTarkowski
# 3  2022-08-06          Fulham    Liverpool      MarekRodák  AntoneeRobinson
# 4  2022-08-07  Leicester City    Brentford       DannyWard     WesleyFofana
#
#      home_player_3    home_player_4    home_player_5     home_player_6  \
# 0        MarcGuéhi   TyrickMitchell  JoachimAndersen    CheickDoucouré
# 1       LloydKelly   JeffersonLerma       BenPearson     PhilipBilling
# 2        YerryMina  NathanPatterson       BenGodfrey  VitaliiMykolenko
# 3  TosinAdarabioyo          TimReam        KennyTete      JoãoPalhinha
# 4       JonnyEvans    DanielAmartey  TimothyCastagne      WilfredNdidi
#
#           home_player_7  ...         referee  match report notes    sh  sot  \
# ...

# %%
matches.shape
# Out:
# (410, 49)

# %%
matches["team"].value_counts()
# Out:
# Newcastle United           24
# Tottenham Hotspur          23
# Aston Villa                23
# Leeds United               22
# Everton                    22
# Chelsea                    22
# Brentford                  22
# West Ham United            22
# Crystal Palace             21
# Arsenal                    21
# Liverpool                  21
# Manchester United          21
# Wolverhampton Wanderers    21
# Southampton                20
# Leicester City             20
# Manchester City            19
# Watford                    13
# Burnley                    13
# Norwich City               12
# Nottingham Forest          11
# Bournemouth                 9
# Fulham                      8
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 18    17
# Matchweek 24    16
# Matchweek 22    16
# Matchweek 15    16
# Matchweek 3     15
# Matchweek 1     14
# Matchweek 10    14
# Matchweek 14    14
# Matchweek 6     13
# Matchweek 11    13
# Matchweek 12    13
# Matchweek 25    13
# Matchweek 27    13
# Matchweek 16    13
# Matchweek 8     12
# Matchweek 5     12
# Matchweek 2     12
# Matchweek 26    12
# Matchweek 7     11
# Matchweek 28    11
# Matchweek 13    11
# Matchweek 4     10
# Matchweek 9     10
# Matchweek 35     9
# Matchweek 37     9
# Matchweek 33     9
# Matchweek 20     9
# Matchweek 23     9
# Matchweek 21     9
# Matchweek 17     9
# Matchweek 31     8
# Matchweek 30     7
# Matchweek 19     7
# Matchweek 29     6
# Matchweek 32     5
# Matchweek 36     5
# Matchweek 34     4
# Matchweek 38     4
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date               object
# team               object
# opponent           object
# home_player_1      object
# home_player_2      object
# home_player_3      object
# home_player_4      object
# home_player_5      object
# home_player_6      object
# home_player_7      object
# home_player_8      object
# home_player_9      object
# home_player_10     object
# home_player_11     object
# away_player_1      object
# away_player_2      object
# away_player_3      object
# away_player_4      object
# away_player_5      object
# away_player_6      object
# away_player_7      object
# away_player_8      object
# away_player_9      object
# away_player_10     object
# away_player_11     object
# time               object
# comp               object
# round              object
# day                object
# venue              object
# result             object
# gf                float64
# ga                float64
# xg                float64
# xga               float64
# ...

# %%
#chaging the data types
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches = matches.dropna(axis=0, subset=['result'])

# %%
#new column target is added. 1 for win, 0 for lose
#matches["target"] = (matches["result"] == "W").astype("int")

# Create the dictionary
event_dictionary ={'W' : 2, 'D' : 1, 'L' : 0}

matches['target'] = matches['result'].map(event_dictionary)

# %%
matches.isnull().sum()
# Out:
# date                0
# team                0
# opponent            0
# home_player_1       0
# home_player_2       0
# home_player_3       0
# home_player_4       0
# home_player_5       0
# home_player_6       0
# home_player_7       0
# home_player_8       0
# home_player_9       0
# home_player_10      0
# home_player_11      0
# away_player_1       0
# away_player_2       0
# away_player_3       0
# away_player_4       0
# away_player_5       0
# away_player_6       0
# away_player_7       0
# away_player_8       0
# away_player_9       0
# away_player_10      0
# away_player_11      0
# time                0
# comp                0
# round               0
# day                 0
# venue               0
# result              0
# gf                  0
# ga                  0
# xg                  0
# xga                 0
# poss                0
# attendance          0
# captain             0
# formation           0
# referee             0
# match report        0
# ...

# %%
#new column venue_code is added, 1 is for Home and 0 is for Away
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches.head(20)
# Out:
#          date                     team         opponent     home_player_1  \
# 0  2022-08-05           Crystal Palace          Arsenal     VicenteGuaita
# 1  2022-08-06              Bournemouth      Aston Villa       MarkTravers
# 2  2022-08-06                  Everton          Chelsea    JordanPickford
# 3  2022-08-06                   Fulham        Liverpool        MarekRodák
# 4  2022-08-07           Leicester City        Brentford         DannyWard
# 5  2022-08-06        Tottenham Hotspur      Southampton        HugoLloris
# 6  2022-08-07          West Ham United  Manchester City   LukaszFabianski
# 7  2022-08-13                  Arsenal   Leicester City     AaronRamsdale
# 8  2022-08-13              Aston Villa          Everton  EmilianoMartínez
# 9  2022-08-15                Liverpool   Crystal Palace           Alisson
# 10 2022-08-13          Manchester City      Bournemouth           Ederson
# 11 2022-08-13              Southampton     Leeds United       GavinBazunu
# ...

# %%
matches.dtypes
# Out:
# date              datetime64[ns]
# team                      object
# opponent                  object
# home_player_1             object
# home_player_2             object
# home_player_3             object
# home_player_4             object
# home_player_5             object
# home_player_6             object
# home_player_7             object
# home_player_8             object
# home_player_9             object
# home_player_10            object
# home_player_11            object
# away_player_1             object
# away_player_2             object
# away_player_3             object
# away_player_4             object
# away_player_5             object
# away_player_6             object
# away_player_7             object
# away_player_8             object
# away_player_9             object
# away_player_10            object
# away_player_11            object
# time                      object
# comp                      object
# round                     object
# ...

# %%
#categorizing the opponent teams
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         date            team     opponent   home_player_1    home_player_2  \
# 0 2022-08-05  Crystal Palace      Arsenal   VicenteGuaita   NathanielClyne
# 1 2022-08-06     Bournemouth  Aston Villa     MarkTravers      ChrisMepham
# 2 2022-08-06         Everton      Chelsea  JordanPickford   JamesTarkowski
# 3 2022-08-06          Fulham    Liverpool      MarekRodák  AntoneeRobinson
# 4 2022-08-07  Leicester City    Brentford       DannyWard     WesleyFofana
#
#      home_player_3    home_player_4    home_player_5     home_player_6  \
# 0        MarcGuéhi   TyrickMitchell  JoachimAndersen    CheickDoucouré
# 1       LloydKelly   JeffersonLerma       BenPearson     PhilipBilling
# 2        YerryMina  NathanPatterson       BenGodfrey  VitaliiMykolenko
# 3  TosinAdarabioyo          TimReam        KennyTete      JoãoPalhinha
# 4       JonnyEvans    DanielAmartey  TimothyCastagne      WilfredNdidi
#
#           home_player_7  ...    sh  sot  dist   fk   pk pkatt season target  \
# ...

# %%
matches.dtypes
# Out:
# date              datetime64[ns]
# team                      object
# opponent                  object
# home_player_1             object
# home_player_2             object
# home_player_3             object
# home_player_4             object
# home_player_5             object
# home_player_6             object
# home_player_7             object
# home_player_8             object
# home_player_9             object
# home_player_10            object
# home_player_11            object
# away_player_1             object
# away_player_2             object
# away_player_3             object
# away_player_4             object
# away_player_5             object
# away_player_6             object
# away_player_7             object
# away_player_8             object
# away_player_9             object
# away_player_10            object
# away_player_11            object
# time                      object
# comp                      object
# round                     object
# ...

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["home_player_1_code"] = matches["home_player_1"].astype("category").cat.codes
matches["home_player_2_code"] = matches["home_player_2"].astype("category").cat.codes
matches["home_player_3_code"] = matches["home_player_3"].astype("category").cat.codes
matches["home_player_4_code"] = matches["home_player_4"].astype("category").cat.codes
matches["home_player_5_code"] = matches["home_player_5"].astype("category").cat.codes
matches["home_player_6_code"] = matches["home_player_6"].astype("category").cat.codes
matches["home_player_7_code"] = matches["home_player_7"].astype("category").cat.codes
matches["home_player_8_code"] = matches["home_player_8"].astype("category").cat.codes
matches["home_player_9_code"] = matches["home_player_9"].astype("category").cat.codes
matches["home_player_10_code"] = matches["home_player_10"].astype("category").cat.codes
matches["home_player_11_code"] = matches["home_player_11"].astype("category").cat.codes
matches["away_player_1_code"] = matches["away_player_1"].astype("category").cat.codes
matches["away_player_2_code"] = matches["away_player_2"].astype("category").cat.codes
matches["away_player_3_code"] = matches["away_player_3"].astype("category").cat.codes
matches["away_player_4_code"] = matches["away_player_4"].astype("category").cat.codes
matches["away_player_5_code"] = matches["away_player_5"].astype("category").cat.codes
matches["away_player_6_code"] = matches["away_player_6"].astype("category").cat.codes
matches["away_player_7_code"] = matches["away_player_7"].astype("category").cat.codes
matches["away_player_8_code"] = matches["away_player_8"].astype("category").cat.codes
matches["away_player_9_code"] = matches["away_player_9"].astype("category").cat.codes
matches["away_player_10_code"] = matches["away_player_10"].astype("category").cat.codes
matches["away_player_11_code"] = matches["away_player_11"].astype("category").cat.codes

# %%
matches.head()
# Out:
#         date            team     opponent   home_player_1    home_player_2  \
# 0 2022-08-05  Crystal Palace      Arsenal   VicenteGuaita   NathanielClyne
# 1 2022-08-06     Bournemouth  Aston Villa     MarkTravers      ChrisMepham
# 2 2022-08-06         Everton      Chelsea  JordanPickford   JamesTarkowski
# 3 2022-08-06          Fulham    Liverpool      MarekRodák  AntoneeRobinson
# 4 2022-08-07  Leicester City    Brentford       DannyWard     WesleyFofana
#
#      home_player_3    home_player_4    home_player_5     home_player_6  \
# 0        MarcGuéhi   TyrickMitchell  JoachimAndersen    CheickDoucouré
# 1       LloydKelly   JeffersonLerma       BenPearson     PhilipBilling
# 2        YerryMina  NathanPatterson       BenGodfrey  VitaliiMykolenko
# 3  TosinAdarabioyo          TimReam        KennyTete      JoãoPalhinha
# 4       JonnyEvans    DanielAmartey  TimothyCastagne      WilfredNdidi
#
#           home_player_7  ... away_player_2_code away_player_3_code  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
train.head()
# Out:
#         date            team     opponent   home_player_1    home_player_2  \
# 0 2022-08-05  Crystal Palace      Arsenal   VicenteGuaita   NathanielClyne
# 1 2022-08-06     Bournemouth  Aston Villa     MarkTravers      ChrisMepham
# 2 2022-08-06         Everton      Chelsea  JordanPickford   JamesTarkowski
# 3 2022-08-06          Fulham    Liverpool      MarekRodák  AntoneeRobinson
# 4 2022-08-07  Leicester City    Brentford       DannyWard     WesleyFofana
#
#      home_player_3    home_player_4    home_player_5     home_player_6  \
# 0        MarcGuéhi   TyrickMitchell  JoachimAndersen    CheickDoucouré
# 1       LloydKelly   JeffersonLerma       BenPearson     PhilipBilling
# 2        YerryMina  NathanPatterson       BenGodfrey  VitaliiMykolenko
# 3  TosinAdarabioyo          TimReam        KennyTete      JoãoPalhinha
# 4       JonnyEvans    DanielAmartey  TimothyCastagne      WilfredNdidi
#
#           home_player_7  ... away_player_2_code away_player_3_code  \
# ...

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
test.head()
# Out:
#          date               team         opponent  home_player_1  \
# 37 2023-03-01            Arsenal          Everton  AaronRamsdale
# 38 2023-01-12             Fulham          Chelsea      BerndLeno
# 39 2023-03-15        Southampton        Brentford    GavinBazunu
# 42 2023-02-08  Manchester United     Leeds United     DaviddeGea
# 64 2023-02-15            Arsenal  Manchester City  AaronRamsdale
#
#         home_player_2       home_player_3     home_player_4  \
# 37           BenWhite  OleksandrZinchenko  GabrielMagalhães
# 38          KennyTete     AntoneeRobinson           TimReam
# 39  KyleWalker-Peters         JanBednarek     RomainPerraud
# 42         DiogoDalot    LisandroMartínez          LukeShaw
# 64   GabrielMagalhães       WilliamSaliba  TakehiroTomiyasu
#
#          home_player_5     home_player_6       home_player_7  ...  \
# 37       WilliamSaliba    MartinØdegaard            Jorginho  ...
# 38     TosinAdarabioyo           Willian        HarrisonReed  ...
# ...

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "home_player_1_code", "home_player_2_code", "home_player_3_code","home_player_4_code","home_player_5_code","home_player_6_code","home_player_7_code","home_player_8_code","home_player_9_code","home_player_10_code","home_player_11_code","away_player_1_code","away_player_2_code","away_player_3_code","away_player_4_code","away_player_5_code","away_player_6_code","away_player_7_code","away_player_8_code","away_player_9_code","away_player_10_code","away_player_11_code",]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.453125

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   0  1   2
# actual
# 0           7  0  11
# 1           5  1   8
# 2          10  1  21

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds, average='micro')
# Out:
# 0.453125

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#           date             team        opponent home_player_1  \
# 217 2021-10-16  Manchester City         Burnley   ZackSteffen
# 228 2021-10-30  Manchester City  Crystal Palace       Ederson
# 243 2021-11-21  Manchester City         Everton       Ederson
# 278 2021-12-14  Manchester City    Leeds United       Ederson
# 299 2022-01-15  Manchester City         Chelsea       Ederson
# 315 2022-02-09  Manchester City       Brentford       Ederson
# 366 2022-04-10  Manchester City       Liverpool       Ederson
# 382 2022-04-23  Manchester City         Watford       Ederson
# 409 2022-05-22  Manchester City     Aston Villa       Ederson
# 10  2022-08-13  Manchester City     Bournemouth       Ederson
# 24  2022-08-27  Manchester City  Crystal Palace       Ederson
# 54  2022-10-08  Manchester City     Southampton       Ederson
# 85  2022-11-05  Manchester City          Fulham       Ederson
# 91  2022-11-12  Manchester City       Brentford       Ederson
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                   date                     team  \
# team
# Arsenal                 220 2021-10-22                  Arsenal
#                         233 2021-11-07                  Arsenal
#                         269 2021-12-11                  Arsenal
#                         292 2022-01-01                  Arsenal
#                         305 2022-01-23                  Arsenal
# ...                                ...                      ...
# Wolverhampton Wanderers 46  2022-09-17  Wolverhampton Wanderers
#                         76  2022-10-23  Wolverhampton Wanderers
#                         96  2022-11-12  Wolverhampton Wanderers
#                         132 2023-02-04  Wolverhampton Wanderers
#                         144 2023-02-18  Wolverhampton Wanderers
#
#                                     opponent  home_player_1     home_player_2  \
# team
# Arsenal                 220      Aston Villa  AaronRamsdale  GabrielMagalhães
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#           date                     team         opponent  home_player_1  \
# 220 2021-10-22                  Arsenal      Aston Villa  AaronRamsdale
# 233 2021-11-07                  Arsenal          Watford  AaronRamsdale
# 269 2021-12-11                  Arsenal      Southampton  AaronRamsdale
# 292 2022-01-01                  Arsenal  Manchester City  AaronRamsdale
# 305 2022-01-23                  Arsenal          Burnley  AaronRamsdale
# ..         ...                      ...              ...            ...
# 46  2022-09-17  Wolverhampton Wanderers  Manchester City         JoséSá
# 76  2022-10-23  Wolverhampton Wanderers   Leicester City         JoséSá
# 96  2022-11-12  Wolverhampton Wanderers          Arsenal         JoséSá
# 132 2023-02-04  Wolverhampton Wanderers        Liverpool         JoséSá
# 144 2023-02-18  Wolverhampton Wanderers      Bournemouth         JoséSá
#
#         home_player_2     home_player_3     home_player_4     home_player_5  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds, average='micro')
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.453125

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date         team         opponent result
# 13       1          2 2023-02-11      Arsenal        Brentford      D
# 14       0          2 2023-02-15      Arsenal  Manchester City      L
# 15       2          2 2023-03-01      Arsenal          Everton      W
# 16       2          2 2023-03-04      Arsenal      Bournemouth      W
# 17       2          2 2023-03-19      Arsenal   Crystal Palace      W
# 33       2          2 2023-01-13  Aston Villa     Leeds United      W
# 34       0          2 2023-02-04  Aston Villa   Leicester City      L
# 35       0          0 2023-02-18  Aston Villa          Arsenal      L
# 36       2          0 2023-03-04  Aston Villa   Crystal Palace      W
# 37       2          0 2023-03-18  Aston Villa      Bournemouth      W
